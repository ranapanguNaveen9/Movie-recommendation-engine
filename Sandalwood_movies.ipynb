# %%
import pandas as pd
import numpy as np

# %%
df_30s = df = pd.read_html("https://en.wikipedia.org/wiki/List_of_Kannada_films_of_the_1930s",
                      match = "Title")
df_30s = df_30s[0]
df_30s
# Out:
#    Year           Title               Director  \
# 0  1934  Sati Sulochana              Y. V. Rao
# 1  1934   Bhakta Dhruva  Parshvanathah Altekar
# 2  1935       Sadaarame     Raja Chandrashekar
# 3  1936   Samsara Nauka         H. L. N. Simha
# 4  1936     Chiranjeevi            K. P. Bhave
# 5  1937   Purandaradasa              B. Chawan
# 6  1937  Rajasuya Yaaga          T.Dwarakanath
#
#                                                 Cast  \
# 0  R. Nagendra Rao, Subbaiah Naidu, Lakshmi Bai, ...
# 1  Master Muthu, T.D warakanath, H. S. Krishnaswa...
# 2  Gubbi Veeranna, K.Ashwathamma, Muraaraachaar, ...
# 3  B. R. Panthulu, M. V. Rajamma, S. K. Padma Dev...
# 4  Devudu, Sharada, Malavalli Sundaramma, Basavar...
# 5  G. Krishnaswamy Iyengar, Tripuraamba, J. T. Ba...
# 6  S. R. Vasudevarao, T. K. Ramamurhty, K. R. See...
#
#              Music Director                Producer                Banner
# 0           R. Nagendra Rao  Shah Chamanlal Dungaji  South India Movitone
# ...

# %%
df_40s = pd.read_html("https://en.wikipedia.org/wiki/List_of_Kannada_films_of_the_1940s",
                      match = "Title")
df_40s = df_40s[0]
df_40s
# Out:
#     Year                Title               Director(s)  \
# 0   1941             Subhadra               C. Pullaiah
# 1   1941          Vasantasena            Ramayyar Sirur
# 2   1942     Bhakta Prahalada            K. Subramanyam
# 3   1943       Jeevana Nataka            Wahab Kashmiri
# 4   1943  Satya Harishchandra           R. Nagendra Rao
# 5   1943     Krishna Sudhaama            K. Subramanyam
# 6   1943                 Vani  K. HirannaiahM. N. Gopal
# 7   1943         Radha Ramana           Jyothisha Sinha
# 8   1946   Hemareddy Mallamma        S. Soundarya Rajan
# 9   1947          Chandrahasa           Shanthesh Patel
# 10  1947         Krishnaleela                C. V. Raju
# 11  1947            Mahananda              T. Janakiram
# 12  1947       Mahathma Kabir           R. Nagendra Rao
# 13  1948        Bhakta Ramdas           D. Kemparaj Urs
# 14  1948       Bhakta Kumbara           Bomman D. Irani
# 15  1948             Bharathi       R. M. Veerabadraiah
# ...

# %%
df_50s = pd.read_html("https://en.wikipedia.org/wiki/List_of_Kannada_films_of_the_1950s",
                      match = "Director")
one_list = []
for i in range(0,len(df_50s)-1):
    df = df_50s[i]
    df["year"] = 1950+i
    one_list.append(df)
df_50s = pd.concat(one_list,ignore_index = True,sort = False)
df_50s
# Out:
#                                    Movie (in Kannada)  \
# 0   Shaneeswara Mahatme (ಶನೀಶ್ವರ ಮಹಾತ್ಮೆŚanīśvara ...
# 1                        Shiva Parvathi (ಶಿವ ಪಾರ್ವತಿ)
# 2                            Jaganmohini (ಜಗನ್ಮೊಹಿನಿ)
# 3                             Thilothamme (ತಿಲೋತ್ತಮೆ)
# 4       Sri Srinivasa Kalyana (ಶ್ರೀ ಶ್ರೀನಿವಾಸ ಕಲ್ಯಾಣ)
# ..                                                ...
# 65                          Dharma Vijaya (ಧರ್ಮ ವಿಜಯ)
# 66         Jagajyothi Basveshwara (ಜಗಜ್ಯೋತಿ ಬಸವೇಶ್ವರ)
# 67             Mahishasura Mardini (ಮಹಿಷಾಸುರ ಮರ್ಧಿನಿ)
# 68    Manege Banda Mahalakshmi (ಮನೆಗೆ ಬಂದ ಮಹಾಲಕ್ಷ್ಮಿ)
# 69                        Mangala Suthra (ಮಂಗಳ ಸೂತ್ರ)
#
#                              Director  \
# 0                         Kempraj Urs
# 1                        T. Janakiram
# 2                    D. Shankar Singh
# 3                 R. M. Veerabadraiah
# 4   D. Shankar Singh B. Vittalacharya
# ..                                ...
# 65                        N. Jaganath
# ...

# %%
2021-1960
# Out:
# 61

# %%
one_list = []
for i in range(0,61):
    df = pd.read_html("https://en.wikipedia.org/wiki/List_of_Kannada_films_of_"+str(1960+i),
                      match = "Title")
    
    if len(df) > 1:
        k = []
        cols = df[0].columns
        for j in range(0,len(df)):
            if len(df[j].columns) >= len(cols):
                df[j] = df[j][cols]
                k.append(df[j])
        df = pd.concat(k,ignore_index = True,sort = False)
        if "Music Director" in df.columns:
            if "Genre" not in df.columns:
                df['Genre'] = np.NaN
                df = df[['Title', 'Director', 'Cast','Genre', 'Music Director']]
                df.columns = ['Title', 'Director', 'Cast','Genre', 'Music']
                df['year'] = 1960+i
                print(1960+i)
            else:
                df = df[['Title', 'Director', 'Cast','Genre', 'Music Director']]
                df.columns = ['Title', 'Director', 'Cast','Genre', 'Music']
                df['year'] = 1960+i
                print(1960+i)
        elif "Music" not in df.columns:
            if "Genre" not in df.columns:
                df['Genre'] = np.NaN
                df['Music'] = np.NaN
                df = df[['Title', 'Director', 'Cast','Genre', 'Music']]
                df['year'] = 1960+i
                print(1960+i)
            else:
                df['Music'] = np.NaN
                df = df[['Title', 'Director', 'Cast','Genre', 'Music']]
                df['year'] = 1960+i
                print(1960+i)
        elif 'Genre' not in df.columns:
            df['Genre'] = np.NaN
            df = df[['Title', 'Director', 'Cast','Genre', 'Music']]
            df['year'] = 1960+i
            print(1960+i)
        else:
            try:
                df = df[['Title', 'Director', 'Cast','Genre', 'Music director']]
                df.columns = ['Title', 'Director', 'Cast','Genre', 'Music']
                df['year'] = 1960+i
                print(1960+i)
            except:
                df = df[['Title', 'Director', 'Cast','Genre', 'Music']]
                df['year'] = 1960+i
                print(1960+i)
            
    else:
        df = df[0]
        if "Music Director" in df.columns:
            if "Genre" not in df.columns:
                df['Genre'] = np.NaN
                df = df[['Title', 'Director', 'Cast','Genre', 'Music Director']]
                df.columns = ['Title', 'Director', 'Cast','Genre', 'Music']
                df['year'] = 1960+i
                print(1960+i)
            else:
                df = df[['Title', 'Director', 'Cast','Genre', 'Music Director']]
                df.columns = ['Title', 'Director', 'Cast','Genre', 'Music']
                df['year'] = 1960+i
                print(1960+i)
        elif "Music" not in df.columns:
            if 'Genre' not in df.columns:
                df['Genre'] = np.NaN
                df['Music'] = np.NaN
                df = df[['Title', 'Director', 'Cast','Genre', 'Music']]
                df['year'] = 1960+i
                print(1960+i) 
            else:
                df['Music'] = np.NaN
                df = df[['Title', 'Director', 'Cast','Genre', 'Music']]
                df['year'] = 1960+i
                print(1960+i) 
        elif 'Genre' not in df.columns:
            df['Genre'] = np.NaN
            df = df[['Title', 'Director', 'Cast','Genre', 'Music']]
            df['year'] = 1960+i
            print(1960+i)
        else:
            try:
                df = df[['Title', 'Director', 'Cast','Genre', 'Music director']]
                df.columns = ['Title', 'Director', 'Cast','Genre', 'Music']
                df['year'] = 1960+i
                print(1960+i)
            except:
                df = df[['Title', 'Director', 'Cast','Genre', 'Music']]
                df['year'] = 1960+i
                print(1960+i)
    one_list.append(df)
# Out:
# 1960
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020

# %%
df6020 = pd.concat(one_list,ignore_index = True, sort = False)

# %%
df6020
# Out:
#                                      Title                 Director  \
# 0     Shivalinga Sakshi (ಶಿವಲಿಂಗ ಸಾಕ್ಷಿ) |         D. Shankar Singh
# 1     Ranadheera Kanteerava (ರಣಧೀರ ಕಂಠೀರವ)              N. C. Rajan
# 2            Rani Honnamma (ರಾಣಿ ಹೊನ್ನಮ್ಮ)  K. R. Seetharama Sastry
# 3              Makkala Rajya (ಮಕ್ಕಳ ರಾಜ್ಯ)             B.R.Panthulu
# 4                Aasha Sundari (ಆಶಾಸುಂದರಿ)     Hunsur Krishnamurthy
# ...                                    ...                      ...
# 4010                                RH 100             Mahesh M. C.
# 4011                               Thanike               Kali Gowda
# 4012                     Avanalli Ivalilli   Sandesh Krishnamoorthy
# 4013                           Prathibimba            Sathwik N. N.
# 4014                              Shakeela         Indrajit Lankesh
#
#                                                    Cast Genre Music  year
# 0                   K. S. Ashwath, Prathima, Udayakumar   NaN   NaN  1960
# ...

# %%
df6020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4015 entries, 0 to 4014
# Data columns (total 6 columns):
# Title       4009 non-null object
# Director    3989 non-null object
# Cast        4000 non-null object
# Genre       1612 non-null object
# Music       2267 non-null object
# year        4015 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 188.3+ KB

# %%
df6020 = df6020[df6020['Title'].notna()]
df6020 = df6020.reset_index(drop = True)

# %%
df_21 = pd.read_html("https://en.wikipedia.org/wiki/List_of_Kannada_films_of_2021",
                      match = "Title")

# %%
len(df_21)
# Out:
# 5

# %%
two_list = []
for i in range(0,len(df_21)-2):
    df = df_21[i][['Title', 'Director', 'Cast']]
    df['Genre'] = np.NaN
    df["Music"] = np.NaN
    df['year'] = 2021
    two_list.append(df)
# Out:
# /home/ug/anaconda3/envs/my_env/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/ug/anaconda3/envs/my_env/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /home/ug/anaconda3/envs/my_env/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_21 = pd.concat(two_list,ignore_index = True, sort = False)

# %%
df_21
# Out:
#                                Title                  Director  \
# 0                         Rajatantra                 PVR Swamy
# 1                      Amruthavahini          K. Narendra Babu
# 2                        Mahishasura             Uday Prasanna
# 3                              Vikky                 S. Ramesh
# 4                       Kathle Kaadu           Raju Devasandra
# 5                              Laddu               R. Ramanand
# 6                             Pantru              Milaan Dhanu
# 7                  Talaq Talaq Talaq              Milaan Dhanu
# 8                    Naanu Nan Jaanu                 Shri Hari
# 9                          Ramarjuna           Anish Tejeshwar
# 10                             Gattu             Firoz H. Khan
# 11                  Inspector Vikram             Sri Narasimha
# 12             Mangalavara Rajaadina                     Yuvin
# 13                            Manjra           Mutthuraj Reddy
# ...

# %%
df_30s['Genre'] = np.NaN
df_30s = df_30s[['Title', 'Director', 'Cast', 'Genre','Music','year']]
df_30s.columns = df6020.columns

# %%
df_40s.columns
# Out:
# Index(['Year', 'Title', 'Director(s)', 'Cast', 'Notes'], dtype='object')

# %%
df_40s["Music Director"] = np.NaN
df_40s['Genre'] = np.NaN
df_40s = df_40s[['Title', 'Director(s)', 'Cast','Genre','Music Director','Year']]
df_40s.columns = df6020.columns

# %%
df_50s.columns
# Out:
# Index(['Title', 'Director', 'Cast', 'Genre', 'Music', 'year'], dtype='object')

# %%
df_50s['Genre'] = np.NaN
df_50s = df_50s[['Title', 'Director', 'Cast','Genre','Music','year']]
df_50s.columns = df6020.columns
# Out:
# /home/ug/anaconda3/envs/my_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
final_list = [df_30s,df_40s,df_50s,df6020,df_21]

# %%
for i in range(0,len(final_list)):
    print(final_list[i].columns)
# Out:
# Index(['Title', 'Director', 'Cast', 'Genre', 'Music', 'year'], dtype='object')
# Index(['Title', 'Director', 'Cast', 'Genre', 'Music', 'year'], dtype='object')
# Index(['Title', 'Director', 'Cast', 'Genre', 'Music', 'year'], dtype='object')
# Index(['Title', 'Director', 'Cast', 'Genre', 'Music', 'year'], dtype='object')
# Index(['Title', 'Director', 'Cast', 'Genre', 'Music', 'year'], dtype='object')

# %%
sandalwood = pd.concat(final_list,ignore_index = True, sort = False)

# %%
sandalwood
# Out:
#                     Title                  Director  \
# 0          Sati Sulochana                 Y. V. Rao
# 1           Bhakta Dhruva     Parshvanathah Altekar
# 2               Sadaarame        Raja Chandrashekar
# 3           Samsara Nauka            H. L. N. Simha
# 4             Chiranjeevi               K. P. Bhave
# ...                   ...                       ...
# 4153      Seetharam Benoy        Devi Prasad Shetty
# 4154  Jeevnane Natka Samy  Raju Bhandari Rajavartha
# 4155              Groufie              Ravi Arjun D
# 4156             Shardula           Aravind Kaushik
# 4157                Lanke                Ram Prasad
#
#                                                    Cast Genre  \
# 0     R. Nagendra Rao, Subbaiah Naidu, Lakshmi Bai, ...   NaN
# 1     Master Muthu, T.D warakanath, H. S. Krishnaswa...   NaN
# 2     Gubbi Veeranna, K.Ashwathamma, Muraaraachaar, ...   NaN
# 3     B. R. Panthulu, M. V. Rajamma, S. K. Padma Dev...   NaN
# ...

# %%
sandalwood = sandalwood[sandalwood['Title'].notna()]
sandalwood = sandalwood.reset_index(drop = True)

# %%
sandalwood['language'] = "Kannada"
sandalwood['industry'] = "Sandalwood"

# %%
sandalwood = sandalwood.drop_duplicates()
sandalwood = sandalwood.reset_index(drop = True)

# %%
sandalwood.to_csv("Sandalwood_movies.csv",header =  True,index = False)

# %%
sandalwood.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4158 entries, 0 to 4157
# Data columns (total 8 columns):
# Title       4158 non-null object
# Director    4138 non-null object
# Cast        4149 non-null object
# Genre       1612 non-null object
# Music       2318 non-null object
# year        4158 non-null int64
# language    4158 non-null object
# industry    4158 non-null object
# dtypes: int64(1), object(7)
# memory usage: 260.0+ KB
