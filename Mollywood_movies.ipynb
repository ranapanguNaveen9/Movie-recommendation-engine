# %%
import pandas as pd
import numpy as np

# %%
# Before 1960
df = pd.read_html("https://en.wikipedia.org/wiki/List_of_Malayalam_films_before_1960",
                      match = 'Screenplay')

# %%
a = df[0]

# %%
a.columns = ["Film","year","Director","story","Screenplay","Cast"]

# %%
a['Genre'] = np.NaN
a['Music'] = np.NaN

# %%
a = a[["Film","Director","Cast",'Genre','Music',"year"]]

# %%
b = df[1]

# %%
b = b[["Movie",'Main actors','Direction','Date','Music']]

# %%
b['Genre'] = np.NaN
# Out:
# /home/ug/anaconda3/envs/my_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def f1(row):
    a = str(row['Date'])[-4:]
    return a

# %%
b["year"] = b.apply(f1,axis = 1)
# Out:
# /home/ug/anaconda3/envs/my_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
b = b[["Movie",'Direction','Main actors','Genre','Music','year']]

# %%
a.columns
# Out:
# Index(['Film', 'Director', 'Cast', 'Genre', 'Music', 'year'], dtype='object')

# %%
b.columns
# Out:
# Index(['Film', 'Director', 'Cast', 'Genre', 'Music', 'year'], dtype='object')

# %%
b.columns = a.columns

# %%
b
# Out:
#                          Film            Director  \
# 0                Nalla Thanka  P. V. Krishna Iyer
# 1                      Chechi       T. Janaki Ram
# 2                  Sasidharan       T. Janaki Ram
# 3                      Sthree    R. Velappan Nair
# 4                    Prasanna    Sri Ramalu Naidu
# ..                        ...                 ...
# 58                      Lilly           F. Nagoor
# 59  Aana Valarthiya Vanampadi      P. Subramaniam
# 60           Minnalppadayaali        G. Viswanath
# 61               Chathurangam       J. D. Thottan
# 62                 Naadodikal       S. Ramanathan
#
#                                                  Cast  Genre  \
# 0   Augustine Joseph, Vaikom Mani, Miss Kumari, Mi...    NaN
# 1                                                 NaN    NaN
# 2                                                 NaN    NaN
# 3        Thikkurissi Sukumaran Nair Vaikom M. P. Mani    NaN
# ...

# %%
df_60s = pd.concat([a,b],ignore_index = True,sort = False)

# %%
df_60s
# Out:
#                          Film        Director  \
# 0              Vigathakumaran    J. C. Daniel
# 1             Marthanda Varma       P. V. Rao
# 2                       Balan      S. Nottani
# 3                  Gnanambika      S. Nottani
# 4                    Prahlada  K. Subramanyam
# ..                        ...             ...
# 65                      Lilly       F. Nagoor
# 66  Aana Valarthiya Vanampadi  P. Subramaniam
# 67           Minnalppadayaali    G. Viswanath
# 68               Chathurangam   J. D. Thottan
# 69                 Naadodikal   S. Ramanathan
#
#                                                  Cast  Genre  \
# 0                            J. C. Daniel, P. K. Rosy    NaN
# 1             Jaidev, A. V. P. Menon, Devaki, Padmini    NaN
# 2        K. K. Aroor, Alleppey Vincent, M. K. Kamalam    NaN
# 3                                                 NaN    NaN
# 4   Guru Gopinath, Thankamani Gopinath, Kumari Lak...    NaN
# ...

# %%
df_60s['year'].unique()
# Out:
# array([1928, 1933, 1938, 1940, 1941, 1948, 1949, '1950', '1951', '1952',
#        '1953', '1954', '1955', '1956', '1957', '1958', '1959'],
#       dtype=object)

# %%
1990-1960
# Out:
# 30

# %%
one_list = []
for i in range(0,31):
    df = pd.read_html("https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_"+str(1960+i),
                      match = 'Film')
    print(len(df))
    if len(df)>1:
        for j in range(0,len(df)):
            if 'Original film' not in df[j].columns:
                if 'Cast' in df[j].columns:
                    if "Basic Language" not in df[j].columns:
                        k = df[j]
        df = k
        if "Music Director" in df.columns:
            if "Genre" not in df.columns:
                df['Genre'] = np.NaN
                df = df[['Film', 'Director', 'Cast','Genre', 'Music Director']]
                df.columns = ['Film', 'Director', 'Cast','Genre', 'Music']
                df['year'] = 1960+i
                print(1960+i)
                print(df.columns)
            else:
                df = df[['Film', 'Director', 'Cast','Genre', 'Music Director']]
                df.columns = ['Film', 'Director', 'Cast','Genre', 'Music']
                df['year'] = 1960+i
                print(1960+i)
                print(df.columns) 
        elif "Music" not in df.columns:
            if "Genre" not in df.columns:
                df['Genre'] = np.NaN
                df['Music'] = np.NaN
                df = df[['Film', 'Director', 'Cast','Genre', 'Music']]
                df['year'] = 1960+i
                print(1960+i)
                print(df.columns)
            else:
                df['Music'] = np.NaN
                df = df[['Film', 'Director', 'Cast','Genre', 'Music']]
                df['year'] = 1960+i
                print(1960+i)
                print(df.columns)
        elif "Genre" not in df.columns:
            df['Genre'] = np.NaN
            df = df[['Film', 'Director', 'Cast','Genre', 'Music']]
            df['year'] = 1960+i
            print(1960+i)
            print(df.columns)
        else:
            try:
                df = df[['Film', 'Director', 'Cast','Genre', 'Music director']]
                df.columns = ['Film', 'Director', 'Cast','Genre', 'Music']
                df['year'] = 1960+i
                print(1960+i)
                print(df.columns)
            except:
                df = df[['Film', 'Director', 'Cast','Genre', 'Music']]
                df['year'] = 1960+i
                print(1960+i)
                print(df.columns)
    else:
        df = df[0]
        if "Music Director" in df.columns:
            if "Genre" not in df.columns:
                df['Genre'] = np.NaN
                df = df[['Film', 'Director', 'Cast','Genre', 'Music Director']]
                df.columns = ['Film', 'Director', 'Cast','Genre', 'Music']
                df['year'] = 1960+i
                print(1960+i)
                print(df.columns)
            else:
                df = df[['Film', 'Director', 'Cast','Genre', 'Music Director']]
                df.columns = ['Film', 'Director', 'Cast','Genre', 'Music']
                df['year'] = 1960+i
                print(1960+i)
                print(df.columns) 
        elif "Music" not in df.columns:
            if "Genre" not in df.columns:
                df['Genre'] = np.NaN
                df['Music'] = np.NaN
                df = df[['Film', 'Director', 'Cast','Genre', 'Music']]
                df['year'] = 1960+i
                print(1960+i)
                print(df.columns)
            else:
                df['Music'] = np.NaN
                df = df[['Film', 'Director', 'Cast','Genre', 'Music']]
                df['year'] = 1960+i
                print(1960+i)
                print(df.columns)
        elif "Genre" not in df.columns:
            df['Genre'] = np.NaN
            df = df[['Film', 'Director', 'Cast','Genre', 'Music']]
            df['year'] = 1960+i
            print(1960+i)
            print(df.columns)
        else:
            try:
                df = df[['Film', 'Director', 'Cast','Genre', 'Music director']]
                df.columns = ['Film', 'Director', 'Cast','Genre', 'Music']
                df['year'] = 1960+i
                print(1960+i)
                print(df.columns)
            except:
                df = df[['Film', 'Director', 'Cast','Genre', 'Music']]
                df['year'] = 1960+i
                print(1960+i)
                print(df.columns)
        #print(df.columns)
    one_list.append(df)
    #print(1960+i)
# Out:
# 1
# 1960
# Index(['Film', 'Director', 'Cast', 'Genre', 'Music', 'year'], dtype='object')
# 1
# 1961
# Index(['Film', 'Director', 'Cast', 'Genre', 'Music', 'year'], dtype='object')
# 2
# 1962
# Index(['Film', 'Director', 'Cast', 'Genre', 'Music', 'year'], dtype='object')
# /home/ug/anaconda3/envs/my_env/lib/python3.7/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1
# 1963
# Index(['Film', 'Director', 'Cast', 'Genre', 'Music', 'year'], dtype='object')
# 1
# 1964
# Index(['Film', 'Director', 'Cast', 'Genre', 'Music', 'year'], dtype='object')
# 1
# 1965
# Index(['Film', 'Director', 'Cast', 'Genre', 'Music', 'year'], dtype='object')
# 1
# 1966
# ...

# %%
df6090 = pd.concat(one_list,ignore_index = True,sort = False)

# %%
df6090.columns = ['Title', 'Director', 'Cast', 'Genre', 'Music', 'year']

# %%
df6090
# Out:
#                             Title           Director  \
# 0                            Umma          Kunchacko
# 1                        Poothali     P. Subramaniam
# 2                           Seeta          Kunchacko
# 3                  Sthreehridayam         JD Thottan
# 4                     Neeli Saali          Kunchacko
# ...                           ...                ...
# 1982                Ponnaranjanam      P. R. S. Babu
# 1983           Kouthuka Varthakal         Thulasidas
# 1984                    Saandhram      Ashokan-Thaha
# 1985  Kuruppinte Kanakku Pustakom  Balachandra Menon
# 1986                    Marupuram        Viji Thampi
#
#                                                 Cast  Genre Music  year
# 0           Thikkurissy Sukumaran Nair, B. S. Saroja    NaN   NaN  1960
# 1                         Thikkurissi Sukumaran Nair    NaN   NaN  1960
# 2                          Prem Nazir, Kushalakumari    NaN   NaN  1960
# ...

# %%
one_list = []

for i in range(0,62):
    df = pd.read_html("https://en.wikipedia.org/wiki/List_of_Malayalam_films_of_"+str(1960+i),
                      match = 'Director')
    
    df = df[0]
    if len(df.columns) > 5:
        if "Film" in df.columns:
            if 'Genre' in df.columns:
                try:
                    df = df[['Film', 'Cast', 'Director','Genre','Music director']]
                    df['year'] = 1960+i
                    print(df.columns)
                    print(1960+i)
                except :
                    df = df[['Film', 'Cast', 'Director','Genre','Music Director']]
                    df.columns = ['Film', 'Cast', 'Director','Genre','Music director']
                    df['year'] = 1960+i
                    print(df.columns)
                    print(1960+i)
            else:
                try :
                    df['Genre'] = np.NaN
                    df = df[['Film', 'Cast', 'Director','Genre','Music director']]
                    df['year'] = 1960+i
                    print(df.columns)
                    print(1960+i)
                except :
                    df['Genre'] = np.NaN
                    df = df[['Film', 'Cast', 'Director','Genre','Music Director']]
                    df.columns = ['Film', 'Cast', 'Director','Genre','Music director']
                    df['year'] = 1960+i
                    print(df.columns)
                    print(1960+i)
        else :
            if 'Genre' not in df.columns:
                df['Genre'] = np.NaN
                df["Music director"] = np.NaN
                df = df[['Title', 'Cast', 'Director','Genre','Music director']]
                df.columns = ['Film', 'Cast', 'Director','Genre','Music director']
                df['year'] = 1960+i
                print(df.columns)
                print(1960+i)
            else:
                df["Music director"] = np.NaN
                df = df[['Title', 'Cast', 'Director','Genre','Music director']]
                df.columns = ['Film', 'Cast', 'Director','Genre','Music director']
                df['year'] = 1960+i
                print(df.columns)
                print(1960+i)
                
    elif len(df.columns) == 4 :
        if 'Genre' in df.columns:
            try:
                df["Music director"] = np.NaN
                df = df[['Film', 'Cast', 'Director','Genre','Music director']]
                df['year'] = 1960+i
                print(df.columns)
                print(1960+i)
            except:
                df["Music director"] = np.NaN
                df = df[['Title', 'Cast', 'Director','Genre','Music director']]
                df.columns = ['Film', 'Cast', 'Director','Genre','Music director']
                df['year'] = 1960+i
                print(df.columns)
                print(1960+i)
        else:
            try:
                df["Music director"] = np.NaN
                df['Genre'] = np.NaN
                df = df[['Film', 'Cast', 'Director','Genre','Music director']]
                df['year'] = 1960+i
                print(df.columns)
                print(1960+i)
            except:
                df["Music director"] = np.NaN
                df['Genre'] = np.NaN
                df = df[['Title', 'Cast', 'Director','Genre','Music director']]
                df.columns = ['Film', 'Cast', 'Director','Genre','Music director']
                df['year'] = 1960+i
                print(df.columns)
                print(1960+i)
    elif len(df.columns) == 5:
        if 'Genre' in df.columns:
            try :
                df["Music director"] = np.NaN
                df = df[['Title', 'Cast', 'Director','Genre','Music director']]
                df.columns = ['Film', 'Cast', 'Director','Genre','Music director']
                df['year'] = 1960+i
                print(df.columns)
                print(1960+i)
            except :
                df["Film"] = df['Title']
                df["Music director"] = np.NaN
                df = df[['Film', 'Cast', 'Director','Genre','Music director']]
                df['year'] = 1960+i
                print(df.columns)
                print(1960+i)
        else:
            try :
                df['Genre'] = np.NaN
                df["Music director"] = np.NaN
                df = df[['Title', 'Cast', 'Director','Genre','Music director']]
                df.columns = ['Film', 'Cast', 'Director','Genre','Music director']
                df['year'] = 1960+i
                print(df.columns)
                print(1960+i)
            except :
                df['Genre'] = np.NaN
                df["Film"] = df['Title']
                df["Music director"] = np.NaN
                df = df[['Film', 'Cast', 'Director','Genre','Music director']]
                df['year'] = 1960+i
                print(df.columns)
                print(1960+i)
    one_list.append(df)
# Out:
# Index(['Film', 'Cast', 'Director', 'Genre', 'Music director', 'year'], dtype='object')
# 1960
# Index(['Film', 'Cast', 'Director', 'Genre', 'Music director', 'year'], dtype='object')
# 1961
# Index(['Film', 'Cast', 'Director', 'Genre', 'Music director', 'year'], dtype='object')
# 1962
# Index(['Film', 'Cast', 'Director', 'Genre', 'Music director', 'year'], dtype='object')
# 1963
# Index(['Film', 'Cast', 'Director', 'Genre', 'Music director', 'year'], dtype='object')
# 1964
# Index(['Film', 'Cast', 'Director', 'Genre', 'Music director', 'year'], dtype='object')
# 1965
# Index(['Film', 'Cast', 'Director', 'Genre', 'Music director', 'year'], dtype='object')
# 1966
# Index(['Film', 'Cast', 'Director', 'Genre', 'Music director', 'year'], dtype='object')
# 1967
# Index(['Film', 'Cast', 'Director', 'Genre', 'Music director', 'year'], dtype='object')
# 1968
# /home/ug/anaconda3/envs/my_env/lib/python3.7/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# ...

# %%
df6021 = pd.concat(one_list,ignore_index = True, sort = False)

# %%
df6021
# Out:
#                 Film                                               Cast  \
# 0               Umma           Thikkurissy Sukumaran Nair, B. S. Saroja
# 1           Poothali                         Thikkurissi Sukumaran Nair
# 2              Seeta                          Prem Nazir, Kushalakumari
# 3     Sthreehridayam     Pappukutty Bhagavathar, T. S. Muthaiah, Ambika
# 4        Neeli Saali                Boban Kunchacko, Bahadoor, Vilasini
# ...              ...                                                ...
# 4800             One  Mammootty, Nimisha Sajayan, Balachandra Menon,...
# 4801           Chiri         Joe John Chacko, Vishak Nair, Aneesh Gopal
# 4802     Innu Muthal              Siju Wilson, Indrans,Smrithi Sugathan
# 4803        Chachaji        Abdul Rahim, Surabhi Lakshmi, Balaji Sharma
# 4804             NaN                                                NaN
#
#                  Director Genre      Music director  year
# ...

# %%
df6021 = df6021[df6021['Film'].notna()]
df6021 = df6021.reset_index(drop = True)

# %%
df6021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4796 entries, 0 to 4795
# Data columns (total 6 columns):
# Film              4796 non-null object
# Cast              4440 non-null object
# Director          4522 non-null object
# Genre             983 non-null object
# Music director    1937 non-null object
# year              4796 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 224.9+ KB

# %%
df6021.columns = ['Film', 'Cast', 'Director', 'Genre', 'Music', 'year']

# %%
mollywood = pd.concat([df_60s,df6021],ignore_index = True, sort = False)

# %%
mollywood
# Out:
#                  Film             Director  \
# 0      Vigathakumaran         J. C. Daniel
# 1     Marthanda Varma            P. V. Rao
# 2               Balan           S. Nottani
# 3          Gnanambika           S. Nottani
# 4            Prahlada       K. Subramanyam
# ...               ...                  ...
# 4861        Biriyaani          Sajin Baabu
# 4862              One  Santhosh Vishwanath
# 4863            Chiri     Joseph P Krishna
# 4864      Innu Muthal      Rejjish Midhila
# 4865         Chachaji          M Hajamoinu
#
#                                                    Cast Genre Music  year
# 0                              J. C. Daniel, P. K. Rosy   NaN   NaN  1928
# 1               Jaidev, A. V. P. Menon, Devaki, Padmini   NaN   NaN  1933
# 2          K. K. Aroor, Alleppey Vincent, M. K. Kamalam   NaN   NaN  1938
# 3                                                   NaN   NaN   NaN  1940
# ...

# %%
mollywood = mollywood[['Film', 'Director','Cast','Genre', 'Music','year']]

# %%
mollywood.columns = ['Title', 'Director','Cast','Genre', 'Music','year']

# %%
mollywood.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4866 entries, 0 to 4865
# Data columns (total 6 columns):
# Title       4866 non-null object
# Director    4591 non-null object
# Cast        4492 non-null object
# Genre       983 non-null object
# Music       1949 non-null object
# year        4866 non-null object
# dtypes: object(6)
# memory usage: 228.2+ KB

# %%
mollywood['language'] = "Malayalam"
mollywood['industry'] = "Mollywood"

# %%
mollywood = mollywood.drop_duplicates()
mollywood = mollywood.reset_index(drop = True)

# %%
mollywood.to_csv("Mollywood_movies.csv",header =  True,index = False)
